# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint
pd.options.display.max_colwidth = 100

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

results = list(establishments.find(query))

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
print(len(results)) # checking length of results

# Display the first document in the results using pprint
pprint(results[0])
# Out:
# 41
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65f387f830dfc3200c4c2cd3'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
results_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print('Rows in DataFrame: ', len(results_df))

# Display the first 10 rows of the DataFrame
results_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  65f387f830dfc3200c4c2cd3   110681                  0
# 1  65f387f830dfc3200c4c3056   612039                  0
# 2  65f387f830dfc3200c4c335d   730933                  0
# 3  65f387f830dfc3200c4c354b   172735                  0
# 4  65f387f830dfc3200c4c3558   172953                  0
# 5  65f387f930dfc3200c4c3ef8   512854                  0
# 6  65f387f930dfc3200c4c411c  1537089                  0
# 7  65f387f930dfc3200c4c5645   155648                  0
# 8  65f387f930dfc3200c4c5a88  1012883                  0
# 9  65f387f930dfc3200c4c629b   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                                             scores  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20}
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceInManagement': 30}
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20}
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceInManagement': 20}
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceInManagement': 20}
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20}
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20}
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceInManagement': 30}
# 8   {'Hygiene': 20, 'Structural': 5, 'ConfidenceInManagement': 20}
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20}
#
#    SchemeType                                                         geocode  \
# 0        FHRS                   {'longitude': 0.27694, 'latitude': 50.769705}
# 1        FHRS                  {'longitude': 1.278721, 'latitude': 51.857536}
# 2        FHRS                   {'longitude': 1.15927, 'latitude': 51.789429}
# 3        FHRS                   {'longitude': 0.10202, 'latitude': 50.770885}
# 4        FHRS                  {'longitude': 0.101446, 'latitude': 50.770724}
# 5        FHRS                  {'longitude': 0.736349, 'latitude': 51.541448}
# 6        FHRS                {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7        FHRS                  {'longitude': 0.602364, 'latitude': 51.591515}
# 8        FHRS  {'longitude': 0.146449998021126, 'latitude': 51.1859474182129}
# 9        FHRS                   {'longitude': 0.462307, 'latitude': 51.57005}
#
#   RightToReply     Distance NewRatingPending  \
# 0               4613.888288            False
# 1               4617.965824            False
# 2               4619.656144            False
# 3               4620.421725            False
# 4               4620.437179            False
# 5               4625.565258            False
# 6               4626.200132            False
# 7               4632.276890            False
# 8               4633.934041            False
# 9               4636.552523            False
#
#                                                                                                   meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 1  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 2  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 3  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 4  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 5  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 6  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 7  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 8  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 9  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
#
#                                                                                  links
# 0   [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/110681'}]
# 1   [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/612039'}]
# 2   [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/730933'}]
# 3   [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/172735'}]
# 4   [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/172953'}]
# 5   [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/512854'}]
# 6  [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/1537089'}]
# 7    [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/155648'}]
# 8   [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1012883'}]
# 9    [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/644109'}]
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"$and": [{"LocalAuthorityName": {'$regex': 'London'}}, 
                  {"RatingValue": {"$gte": 4}}]}


results = list(establishments.find(query))

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
print(len(results)) # checking length of results

# Display the first document in the results using pprint
pprint(results[0])
# Out:
# 33
# 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65f387f930dfc3200c4c46ec'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
results_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print('Rows in DataFrame: ', len(results_df))

# Display the first 10 rows of the DataFrame
results_df.head(10)
# Out:
# Rows in DataFrame:  33
#                         _id   FHRSID  ChangesByServerID  \
# 0  65f387f930dfc3200c4c46ec   621707                  0
# 1  65f387f930dfc3200c4c4a2e  1130836                  0
# 2  65f387f930dfc3200c4c5562   293783                  0
# 3  65f387f930dfc3200c4c6360   294474                  0
# 4  65f387f930dfc3200c4c6361  1315095                  0
# 5  65f387f930dfc3200c4c6a67   294900                  0
# 6  65f387fa30dfc3200c4c8b89   293756                  0
# 7  65f387fa30dfc3200c4c8f3b   878523                  0
# 8  65f387fa30dfc3200c4c8f57   293772                  0
# 9  65f387fa30dfc3200c4c8f58   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# 4             PI/000036464  Coombs Catering t/a The Lock and Key
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                               AddressLine1  \
# 0               Oak Apple Farm Building 103 Sheernes Docks
# 1                                       Cherry Garden Pier
# 2                                               Ferry Road
# 3                                Tenants Row Tilbury Docks
# 4                                        Leslie Ford House
# 5  Reeds River Cruises LtdKings ReachRiver ThamesSouthwark
# 6    Funcraft UK Ltd King George V Dock Woolwich Manor Way
# 7                             Air side London City Airport
# 8                        Duty Free Shop Passenger Terminal
# 9                                      London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                         Tilbury Essex               ...
# 4                               Tilbury     Charlton  ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                      LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 1  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 2  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 3  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 4  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 5  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 6  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 7  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 8  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
# 9  http://www.cityoflondon.gov.uk/Corporation/homepage.htm
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                                           scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5}        FHRS
# 1   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0}        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10}        FHRS
# 3   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}        FHRS
# 4   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0}        FHRS
# 5   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}        FHRS
# 6   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5}        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5}        FHRS
# 8   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}        FHRS
# 9   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}        FHRS
#
#                                                            geocode  \
# 0                   {'longitude': 0.508551, 'latitude': 51.369321}
# 1   {'longitude': 0.249255999922752, 'latitude': 51.1236228942871}
# 2                   {'longitude': 0.561954, 'latitude': 51.543831}
# 3                   {'longitude': 0.346325, 'latitude': 51.464078}
# 4   {'longitude': 0.346336990594864, 'latitude': 51.4640655517578}
# 5                   {'longitude': 0.287555, 'latitude': 51.504071}
# 6                   {'longitude': 0.069286, 'latitude': 51.501121}
# 7                   {'longitude': 0.048006, 'latitude': 51.503733}
# 8                   {'longitude': 0.047966, 'latitude': 51.504112}
# 9  {'longitude': 0.0479655750095844, 'latitude': 51.5041122436523}
#
#   RightToReply     Distance NewRatingPending  \
# 0               4627.439468            False
# 1               4627.873179            False
# 2               4631.968418            False
# 3               4636.847650            False
# 4               4636.846754            False
# 5               4640.460834            False
# 6               4648.301822            False
# 7               4649.173485            False
# 8               4649.188826            False
# 9               4649.188850            False
#
#                                                                                                   meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 1  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 2  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 3  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 4  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 5  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 6  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 7  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 8  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
# 9  {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '...
#
#                                                                                 links
# 0  [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/621707'}]
# 1  [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1130836'}]
# 2   [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/293783'}]
# 3   [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/294474'}]
# 4  [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1315095'}]
# 5   [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/294900'}]
# 6   [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/293756'}]
# 7   [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/878523'}]
# 8   [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/293772'}]
# 9   [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/294606'}]
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 0.084
longitude = 51.49

query = {"RatingValue": 5, 
         'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)},
         'geocode.longitude': {'$lte': (longitude + degree_search), '$gte': (longitude - degree_search)}
}

sort = [('scores.Hygiene', -1)] # -1 = descending, 1 = ascending

limit = 5

# Print the results
for result in establishments.find(query).sort(sort).limit(limit):
    pprint(result)

# %%
# Convert result to Pandas DataFrame
results_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print('Rows in DataFrame: ', len(results_df))

# Display the first 10 rows of the DataFrame
results_df.head(10)

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame
results_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print('Rows in DataFrame: ', len(results_df))

# Display the first 10 rows of the DataFrame
results_df.head(10)
